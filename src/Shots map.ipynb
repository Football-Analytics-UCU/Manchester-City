# %%
# !pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch, VerticalPitch
import seaborn as sns

# %%
df = pd.read_csv('events_1729243.csv')

# %%
df_shorten = df[['period', 'minute', 'second', 'type', 'outcome_type', 'team_id', 'team', 'x', 'y']]

# %%
df_shorten
# Out:
#           period  minute  second          type outcome_type  team_id  \
# 0       PreMatch       0     0.0  FormationSet   Successful       15
# 1       PreMatch       0     0.0  FormationSet   Successful      167
# 2      FirstHalf       0     0.0         Start   Successful      167
# 3      FirstHalf       0     0.0         Start   Successful       15
# 4      FirstHalf       0     0.0          Pass   Successful       15
# ...          ...     ...     ...           ...          ...      ...
# 1594  SecondHalf      67    37.0          Pass   Successful      167
# 1595  SecondHalf      67    40.0          Pass   Successful      167
# 1596  SecondHalf      71    57.0          Pass   Successful       15
# 1597  SecondHalf      80    30.0          Pass   Successful      167
# 1598  SecondHalf      90    21.0          Pass   Successful       15
#
#           team     x     y
# 0      Chelsea   0.0   0.0
# 1     Man City   0.0   0.0
# 2     Man City   0.0   0.0
# ...

# %%
df_shots = df_shorten[df_shorten['type'].isin(['MissedShots', 'SavedShot', 'Goal'])]

# %%
df_shots
# Out:
#           period  minute  second         type outcome_type  team_id      team  \
# 14     FirstHalf       0    25.0    SavedShot   Successful       15   Chelsea
# 218    FirstHalf      11    37.0    SavedShot   Successful       15   Chelsea
# 284    FirstHalf      15    35.0    SavedShot   Successful      167  Man City
# 289    FirstHalf      16     6.0    SavedShot   Successful      167  Man City
# 326    FirstHalf      18    14.0    SavedShot   Successful       15   Chelsea
# 376    FirstHalf      24     3.0         Goal   Successful      167  Man City
# 407    FirstHalf      26    26.0    SavedShot   Successful       15   Chelsea
# 414    FirstHalf      27    50.0    SavedShot   Successful       15   Chelsea
# 419    FirstHalf      28    24.0         Goal   Successful       15   Chelsea
# 460    FirstHalf      31    40.0  MissedShots   Successful      167  Man City
# 494    FirstHalf      33    51.0  MissedShots   Successful      167  Man City
# ...

# %%
df_shots['type'] = df_shots['type'].replace({'MissedShots': 'MissedShot'})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12444\917243886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots['type'] = df_shots['type'].replace({'MissedShots': 'MissedShot'})

# %%
df_shots
# Out:
#           period  minute  second        type outcome_type  team_id      team  \
# 14     FirstHalf       0    25.0   SavedShot   Successful       15   Chelsea
# 218    FirstHalf      11    37.0   SavedShot   Successful       15   Chelsea
# 284    FirstHalf      15    35.0   SavedShot   Successful      167  Man City
# 289    FirstHalf      16     6.0   SavedShot   Successful      167  Man City
# 326    FirstHalf      18    14.0   SavedShot   Successful       15   Chelsea
# 376    FirstHalf      24     3.0        Goal   Successful      167  Man City
# 407    FirstHalf      26    26.0   SavedShot   Successful       15   Chelsea
# 414    FirstHalf      27    50.0   SavedShot   Successful       15   Chelsea
# 419    FirstHalf      28    24.0        Goal   Successful       15   Chelsea
# 460    FirstHalf      31    40.0  MissedShot   Successful      167  Man City
# 494    FirstHalf      33    51.0  MissedShot   Successful      167  Man City
# ...

# %%
df_shots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 14 to 1499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   period        32 non-null     object
#  1   minute        32 non-null     int64
#  2   second        32 non-null     float64
#  3   type          32 non-null     object
#  4   outcome_type  32 non-null     object
#  5   team_id       32 non-null     int64
#  6   team          32 non-null     object
#  7   x             32 non-null     float64
#  8   y             32 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.5+ KB

# %%
chelsea_shots = df_shots[df_shots['team'] == 'Chelsea']

# %%
#Convert the data into mplsoccer pitch
chelsea_shots ['x'] = chelsea_shots ['x']*1.2
chelsea_shots ['y'] = chelsea_shots ['y']*.8
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12444\2207518846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chelsea_shots ['x'] = chelsea_shots ['x']*1.2
# C:\Users\User\AppData\Local\Temp\ipykernel_12444\2207518846.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chelsea_shots ['y'] = chelsea_shots ['y']*.8

# %%
# Create the pitch
fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

# Draw the pitch
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc', half=True)
pitch.draw(ax=ax)

plt.gca().invert_xaxis()

# Plot shots on the pitch
colors = {'MissedShot': 'red', 'SavedShot': 'blue', 'Goal': 'green'}
for shot_type, color in colors.items():
    subset = chelsea_shots[chelsea_shots['type'] == shot_type]
    ax.scatter(subset['x'], subset['y'], color=color, label=shot_type, zorder=5)
    
ax.legend()
plt.title('Chelsea_Shots', c='w', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Chelsea_Shots')

# %%
man_city_shots = df_shots[df_shots['team'] == 'Man City']

# %%
#Convert the data into mplsoccer pitch
man_city_shots ['x'] = man_city_shots ['x']*1.2
man_city_shots ['y'] = man_city_shots ['y']*.8
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12444\1009119580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   man_city_shots ['x'] = man_city_shots ['x']*1.2
# C:\Users\User\AppData\Local\Temp\ipykernel_12444\1009119580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   man_city_shots ['y'] = man_city_shots ['y']*.8

# %%
# Create the pitch
fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

# Draw the pitch
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc', half=True)
pitch.draw(ax=ax)

plt.gca().invert_xaxis()

# Plot shots on the pitch
colors = {'MissedShot': 'red', 'SavedShot': 'blue', 'Goal': 'green'}
for shot_type, color in colors.items():
    subset = man_city_shots[man_city_shots['type'] == shot_type]
    ax.scatter(subset['x'], subset['y'], color=color, label=shot_type, zorder=5)
    
ax.legend()
plt.title('Man City_Shots', c='w', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Man City_Shots')
