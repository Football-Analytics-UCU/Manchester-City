# %%
import ScraperFC as sfc
import pandas as pd

# %%
scraper = sfc.FBRef()
df = scraper.scrape_matches(2024, 'EPL')
# Out:
# Gathering 2024 EPL match links.
# Scraping matches.
#   0%|          | 0/199 [00:00<?, ?it/s]
# c:\Users\avd1ev\miniconda3\envs\ucu\Lib\site-packages\ScraperFC\FBRef.py:556: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   summary_df = pd.read_html(str(summary_tag[0]))[0] if len(summary_tag)==1 else None
# c:\Users\avd1ev\miniconda3\envs\ucu\Lib\site-packages\ScraperFC\FBRef.py:560: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   gk_df = pd.read_html(str(gk_tag[0]))[0] if len(gk_tag)==1 else None
# ...

# %%
df.to_csv('../data/FBRef/matches_season_2023-2024.csv')
